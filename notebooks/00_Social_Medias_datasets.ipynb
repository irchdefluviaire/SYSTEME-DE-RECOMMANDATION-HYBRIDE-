# %%
import pandas as pd

# %%
from datasets import load_dataset

ds = load_dataset("xanderios/linkedin-job-postings")
df = ds["train"].to_pandas()

cameroon_jobs = df[
    df.astype(str)
      .apply(lambda row: row.str.contains("Cameroon|Cameroun|Yaounde|Yaoundé|Douala", case=False, na=False))
      .any(axis=1)
]

cameroon_jobs.to_parquet("data/linkedin_jobs_cameroon.parquet", index=False)
print(cameroon_jobs.shape)
print(cameroon_jobs.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 12
#       8       .apply(lambda row: row.str.contains("Cameroon|Cameroun|Yaounde|Yaoundé|Douala", case=False, na=False))
#       9       .any(axis=1)
#      10 ]
#      11
# ---> 12 cameroon_jobs.to_parquet("data/linkedin_jobs_cameroon.parquet", index=False)
#      13 print(cameroon_jobs.shape)
#      14 print(cameroon_jobs.head())
#
# File c:\Users\Ultra Tech\AppData\Local\pypoetry\Cache\virtualenvs\pre-test-systeme-de-recommandation-kazsorZp-py3.13\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
# ...

# %%
df = dataset["train"].to_pandas()

print(df.head())
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
# ...

# %%
df.shape
# Out:
# (33246, 28)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  str
#  3   description                 33245 non-null  str
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  str
#  8   formatted_work_type         33246 non-null  str
#  9   location                    33246 non-null  str
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  float64
#  12  remote_allowed              4802 non-null   float64
# ...

# %%
variables_list = ["title", "location", "description","posting_domain","scraped",
"job_posting_url","remote_allowed","min_salary","currency"]

donnee = df[variables_list]
donnee.head()
# Out:
#                                                title          location  \
# 0                              Hearing Care Provider  Little River, SC
# 1  Shipping & Receiving Associate 2nd shift (Beav...    Beaver Dam, WI
# 2                               Manager, Engineering      Bessemer, AL
# 3                                               Cook   Aliso Viejo, CA
# 4        Principal Cloud Security Architect (Remote)     United States
#
#                                          description  \
# 0  Overview\n\nHearingLife is a national hearing ...
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...
# 2  \nThe TSUBAKI name is synonymous with excellen...
# 3  descriptionTitle\n\n Looking for a great oppor...
# 4  Job Summary\nAt iHerb, we are on a mission to ...
#
#              posting_domain     scraped  \
# 0  careers-demant.icims.com  1699138101
# 1       www.click2apply.net  1699085420
# 2       www.click2apply.net  1699085644
# 3           jobs.apploi.com  1699087461
# ...

# %%
donnee["currency"].value_counts()
# Out:
# currency
# USD    13352
# Name: count, dtype: int64

# %%
donnee.to_excel("linkedin_job_postings.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 donnee.to_excel("linkedin_job_postings.xlsx", index=False)
#
# File c:\Users\Ultra Tech\AppData\Local\pypoetry\Cache\virtualenvs\pre-test-systeme-de-recommandation-kazsorZp-py3.13\Lib\site-packages\pandas\core\generic.py:2312, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2308             merge_cells=merge_cells,
#    2309             inf_rep=inf_rep,
#    2310             autofilter=autofilter,
#    2311         )
# -> 2312         formatter.write(
#    2313             excel_writer,
#    2314             sheet_name=sheet_name,
#    2315             startrow=startrow,
#
# ...
